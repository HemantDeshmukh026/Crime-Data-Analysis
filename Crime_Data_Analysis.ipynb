# %% [markdown]
# **Topic: Cleaning and Analyzing Crime Data**
#
# **Objective:**
# - In this project, you will work with a real-world dataset containing crime data from 2020 to the present. Your goal is to clean and prepare the dataset for analysis, perform exploratory data analysis, and answer specific questions related to crime trends, patterns, and factors influencing crime rates.
#
# **Dataset:**
# - You will use the crime dataset available at Crime Data from 2020 to Present.
#
# **Tasks:**

# %% [markdown]
# **1. Data Acquisition: Download the dataset from the provided link and load it into your preferred data analysis tool**

# %% [markdown]
# #### 2. Data Inspection:

# %%
import pandas as pd

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820599 entries, 0 to 820598
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Part 1-2        820599 non-null  int64
#  8   Crm Cd          820599 non-null  int64
#  9   Crm Cd Desc     820599 non-null  object
#  10  Mocodes         707114 non-null  object
#  11  Vict Age        820599 non-null  int64
#  12  Vict Sex        712653 non-null  object
#  13  Vict Descent    712645 non-null  object
#  14  Premis Cd       820589 non-null  float64
#  15  Premis Desc     820116 non-null  object
# ...

# %%
df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  8.205990e+05  820599.000000  820599.000000  820599.000000
# mean   2.161299e+08    1335.627492      10.711722    1117.592487
# std    1.083045e+07     654.020941       6.093656     609.360686
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.102046e+08     900.000000       6.000000     621.000000
# 50%    2.201176e+08    1415.000000      11.000000    1142.000000
# 75%    2.220056e+08    1900.000000      16.000000    1617.000000
# max    2.399165e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  820599.000000  820599.000000  820599.000000  820589.000000
# mean        1.413828     500.803992      29.806031     305.759386
# std         0.492519     207.807715      21.776511     216.670080
# min         1.000000     110.000000      -3.000000     101.000000
# ...

# %% [markdown]
# **2.2 Check the data types of each column:**

# %%
columns_data_type=df.dtypes
columns_data_type
# Out:
# DR_NO                       int64
# Date Rptd                  object
# Date Occured       datetime64[ns]
# AREA                        int64
# AREA NAME                  object
# Rpt Dist No                 int64
# Crm Cd                      int64
# Crm Cd Desc                object
# Vict Age                    int64
# Vict Sex                   object
# Vict Descent               object
# Premis Cd                   int32
# Premis Desc_x              object
# Weapon Used Cd              int32
# Weapon Desc                object
# Status                     object
# Status Desc                object
# LOCATION                   object
# LAT                       float64
# LON                       float64
# Month                   period[M]
# Year                        int64
# Day                         int64
# Hour                        int64
# DT                 datetime64[ns]
# Day_of_Week                object
# Date_                      object
# ...

# %% [markdown]
# **2.3 Review column names and descriptions, if available**

# %%
column_descriptions = {
    "DR_NO": "Report Number",
    "Date Rptd": "Date when the incident was reported",
    "DATE OCC": "Date of Occurrence of the incident",
    "TIME OCC": "Time of Occurrence of the incident",
    "AREA": "Numeric code representing the area",
    "AREA NAME": "Name of the area",
    "Rpt Dist No": "Report District Number",
    "Part 1-2": "Type of crime",
    "Crm Cd": "Crime Code",
    "Crm Cd Desc": "Description of the Crime",
    "Mocodes": "Modus Operandi (Method used in the crime)",
    "Vict Age": "Age of the victim",
    "Vict Sex": "Gender of the victim",
    "Vict Descent": "Descent of the victim (e.g., ethnicity or race)",
    "Premis Cd": "Premises Code",
    "Premis Desc": "Description of the Premises",
    "Weapon Used Cd": "Weapon Code (if applicable)",
    "Weapon Desc": "Description of the Weapon Used (if applicable)",
    "Status": "Current status of the case",
    "Status Desc": "Description of the Status",
    "Crm Cd 1": "Additional Crime Code",
    "Crm Cd 2": "Additional Crime Code",
    "Crm Cd 3": "Additional Crime Code",
    "Crm Cd 4": "Additional Crime Code",
    "LOCATION": "Location of the incident",
    "Cross Street": "Cross street or nearby location",
    "LAT": "Latitude coordinates of the incident",
    "LON": "Longitude coordinates of the incident"
}

for column_name, description in column_descriptions.items():
    print(f"{column_name}: {description}")
# Out:
# DR_NO: Report Number
# Date Rptd: Date when the incident was reported
# DATE OCC: Date of Occurrence of the incident
# TIME OCC: Time of Occurrence of the incident
# AREA: Numeric code representing the area
# AREA NAME: Name of the area
# Rpt Dist No: Report District Number
# Part 1-2: Type of crime
# Crm Cd: Crime Code
# Crm Cd Desc: Description of the Crime
# Mocodes: Modus Operandi (Method used in the crime)
# Vict Age: Age of the victim
# Vict Sex: Gender of the victim
# Vict Descent: Descent of the victim (e.g., ethnicity or race)
# Premis Cd: Premises Code
# Premis Desc: Description of the Premises
# Weapon Used Cd: Weapon Code (if applicable)
# Weapon Desc: Description of the Weapon Used (if applicable)
# Status: Current status of the case
# Status Desc: Description of the Status
# Crm Cd 1: Additional Crime Code
# Crm Cd 2: Additional Crime Code
# Crm Cd 3: Additional Crime Code
# Crm Cd 4: Additional Crime Code
# LOCATION: Location of the incident
# ...

# %% [markdown]
# #### 3 Data Cleaning:

# %% [markdown]
# **Identify and handle missing data appropriately.**

# %%
#Removing null values one by one
#Columns with null values are mentioned below
#Mocodes
#Vict Sex
#Vict Descent
#Premis Cd
#Weapon Used Cd
#Weapon Desc
#Crm Cd 1
#Crm Cd 2
#Crm Cd 3
#Crm Cd 4
#Cross Street

# %%
df['Mocodes'].value_counts()
# Out:
# 0344                                       33541
# 0329                                       18305
# 1822 0344                                  10070
# 1501                                        8025
# 0344 1822                                   7026
#                                            ...
# 1309 0913 0302 1606 0907 2018 0344             1
# 0344 0913 0603 0361 0329                       1
# 1822 0314 0344 0352 0209                       1
# 2004 0344 0446 0913 1817                       1
# 0913 0448 0305 0417 0416 0400 0432 0852        1
# Name: Mocodes, Length: 273856, dtype: int64

# %%
#mocodes have multiple values in it, it can't be used in any way for analysis as, there is no description or any information on it.
df.drop(['Mocodes'], axis =1, inplace = True )

# %%
df['Vict Sex'].value_counts()
# Out:
# M    338824
# F    302250
# X     71488
# H        90
# -         1
# Name: Vict Sex, dtype: int64

# %%
df['Vict Sex'].fillna('L', inplace = True)
df['Vict Sex'].isnull().sum()
df['Vict Sex'].mask(df['Vict Sex'] == 'X','L', inplace=True)
df['Vict Sex'].mask(df['Vict Sex'] == 'H','L', inplace=True)
df['Vict Sex'].mask(df['Vict Sex'] == '-','L', inplace=True)
#We are categorising the genger of the victim as Male, Female and LGBTQI+

# %%
df['Vict Sex'].value_counts()
# Out:
# M    338824
# F    302250
# L    179525
# Name: Vict Sex, dtype: int64

# %%
df['Vict Descent'].value_counts()
# Out:
# H    251794
# W    167251
# B    116969
# X     78989
# O     64994
# A     17959
# K      4369
# F      3408
# C      3141
# J      1140
# V       846
# I       771
# Z       412
# P       219
# U       167
# D        61
# G        58
# L        50
# S        45
# -         2
# Name: Vict Descent, dtype: int64

# %%
df['Vict Descent'].fillna('-',inplace = True)

# %%
df['Vict Descent'].value_counts()
# Out:
# H    251794
# W    167251
# B    116969
# -    107956
# X     78989
# O     64994
# A     17959
# K      4369
# F      3408
# C      3141
# J      1140
# V       846
# I       771
# Z       412
# P       219
# U       167
# D        61
# G        58
# L        50
# S        45
# Name: Vict Descent, dtype: int64

# %%
df['Premis Cd'].value_counts()
# Out:
# 101.0    207601
# 501.0    139088
# 502.0    100823
# 108.0     57521
# 203.0     38567
#           ...
# 974.0         2
# 715.0         2
# 891.0         2
# 137.0         1
# 976.0         1
# Name: Premis Cd, Length: 313, dtype: int64

# %%
df2 = df[['Premis Cd', 'Premis Desc']]

# %%
df2.drop_duplicates(keep ='first', inplace = True )
df2.dropna(axis=0,inplace=True)
df2.dropna(axis=1,inplace=True)
# Out:
# <ipython-input-49-4892c57fffdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop_duplicates(keep ='first', inplace = True )
# <ipython-input-49-4892c57fffdb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(axis=0,inplace=True)
# <ipython-input-49-4892c57fffdb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(axis=1,inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 0 to 633502
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Premis Cd    307 non-null    float64
#  1   Premis Desc  307 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 7.2+ KB

# %%
result = pd.merge(df, df2, how="left", on=["Premis Cd", "Premis Cd"])

# %%
df = result

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Part 1-2        820599 non-null  int64
#  8   Crm Cd          820599 non-null  int64
#  9   Crm Cd Desc     820599 non-null  object
#  10  Vict Age        820599 non-null  int64
#  11  Vict Sex        820599 non-null  object
#  12  Vict Descent    820599 non-null  object
#  13  Premis Cd       820589 non-null  float64
#  14  Premis Desc_x   820116 non-null  object
#  15  Weapon Used Cd  286078 non-null  float64
# ...

# %%
df['Premis Desc_x'].fillna('OTHER/OUTSIDE',inplace=True)
df.loc[result['Premis Desc_x'] == 'OTHER/OUTSIDE', 'Premis Cd'] = 116

# %%
df.drop(['Part 1-2'],axis=1,inplace=True)

# %%
df.drop(['Crm Cd 1'],axis=1,inplace=True)
df.drop(['Crm Cd 2'],axis=1,inplace=True)
df.drop(['Crm Cd 3'],axis=1,inplace=True)
df.drop(['Crm Cd 4'],axis=1,inplace=True)

# %%
df.info()
#result = df[['Weapon Used Cd','Weapon Desc']]
#result.dropna(axis=0,inplace=True)
#result.dropna(axis=1,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Crm Cd          820599 non-null  int64
#  8   Crm Cd Desc     820599 non-null  object
#  9   Vict Age        820599 non-null  int64
#  10  Vict Sex        820599 non-null  object
#  11  Vict Descent    820599 non-null  object
#  12  Premis Cd       820599 non-null  float64
#  13  Premis Desc_x   820599 non-null  object
#  14  Weapon Used Cd  286078 non-null  float64
#  15  Weapon Desc     286078 non-null  object
# ...

# %%
df['Weapon Desc'].value_counts()
# Out:
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    153313
# UNKNOWN WEAPON/OTHER WEAPON                        30325
# VERBAL THREAT                                      20969
# HAND GUN                                           17696
# SEMI-AUTOMATIC PISTOL                               6451
#                                                    ...
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    3
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    2
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          1
# Name: Weapon Desc, Length: 79, dtype: int64

# %%
df['Weapon Desc'].fillna('UNKNOWN WEAPON/OTHER WEAPON',inplace=True)
#df = pd.merge(df, result, how="left", on=["Weapon Used Cd", "Weapon Desc"])

# %%
df[df['Weapon Desc']=='UNKNOWN WEAPON/OTHER WEAPON']
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# 5       200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30
# ...           ...                     ...                     ...       ...
# 820593  231110961  07/09/2023 12:00:00 AM  07/06/2023 12:00:00 AM      1200
# 820594  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 820596  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 820597  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 820598  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Crm Cd  \
# ...

# %%
df.loc[result['Weapon Desc'] == 'OTHER/OUTSIDE', 'Weapon Used Cd'] = 500

# %%
df['Weapon Used Cd'].fillna(500,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Crm Cd          820599 non-null  int64
#  8   Crm Cd Desc     820599 non-null  object
#  9   Vict Age        820599 non-null  int64
#  10  Vict Sex        820599 non-null  object
#  11  Vict Descent    820599 non-null  object
#  12  Premis Cd       820599 non-null  float64
#  13  Premis Desc_x   820599 non-null  object
#  14  Weapon Used Cd  820599 non-null  float64
#  15  Weapon Desc     820599 non-null  object
# ...

# %%
df.drop(['Cross Street'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Crm Cd          820599 non-null  int64
#  8   Crm Cd Desc     820599 non-null  object
#  9   Vict Age        820599 non-null  int64
#  10  Vict Sex        820599 non-null  object
#  11  Vict Descent    820599 non-null  object
#  12  Premis Cd       820599 non-null  float64
#  13  Premis Desc_x   820599 non-null  object
#  14  Weapon Used Cd  820599 non-null  float64
#  15  Weapon Desc     820599 non-null  object
# ...

# %%
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])
df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)

# Merge the 'DATE OCC' and 'TIME OCC' columns
df['DateTime'] = df['DATE OCC'].dt.strftime('%Y-%m-%d') + ' ' + df['TIME OCC'].str[:2] + ':' + df['TIME OCC'].str[2:]

# %%
df.head()
# Out:
#        DR_NO               Date Rptd   DATE OCC TIME OCC  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08     2230     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01     0330     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13     1200     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01     1730    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01     0415    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
# ...

# %%
#df[['Date Rptd','DATE OCC','TIME OCC']]
# Out:
#         Date Rptd   DATE OCC        TIME OCC
# 0      2020-01-08 2020-01-08 1 days 13:10:00
# 1      2020-01-02 2020-01-01 0 days 05:30:00
# 2      2020-04-14 2020-02-13 0 days 20:00:00
# 3      2020-01-01 2020-01-01 1 days 04:50:00
# 4      2020-01-01 2020-01-01 0 days 06:55:00
# ...           ...        ...             ...
# 811658 2023-01-27 2023-01-26 1 days 06:00:00
# 811659 2023-03-22 2023-03-22 0 days 16:40:00
# 811660 2023-04-12 2023-04-12 1 days 03:10:00
# 811661 2023-07-02 2023-07-01 0 days 00:01:00
# 811662 2023-03-05 2023-03-05 0 days 15:00:00
#
# [811663 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  datetime64[ns]
#  3   TIME OCC        820599 non-null  object
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Crm Cd          820599 non-null  int64
#  8   Crm Cd Desc     820599 non-null  object
#  9   Vict Age        820599 non-null  int64
#  10  Vict Sex        820599 non-null  object
#  11  Vict Descent    820599 non-null  object
#  12  Premis Cd       820599 non-null  float64
#  13  Premis Desc_x   820599 non-null  object
#  14  Weapon Used Cd  820599 non-null  float64
#  15  Weapon Desc     820599 non-null  object
# ...

# %%
df = df.drop(['DATE OCC', 'TIME OCC'], axis=1)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd  AREA    AREA NAME  Rpt Dist No  Crm Cd  \
# 0   10304468  01/08/2020 12:00:00 AM     3    Southwest          377     624
# 1  190101086  01/02/2020 12:00:00 AM     1      Central          163     624
# 2  200110444  04/14/2020 12:00:00 AM     1      Central          155     845
# 3  191501505  01/01/2020 12:00:00 AM    15  N Hollywood         1543     745
# 4  191921269  01/01/2020 12:00:00 AM    19      Mission         1998     740
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0                           BATTERY - SIMPLE ASSAULT        36        F
# 1                           BATTERY - SIMPLE ASSAULT        25        M
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0        L
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76        F
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31        L
#
#   Vict Descent  ...                                 Premis Desc_x  \
# ...

# %%
column = df.pop('DateTime')
df.insert(2, column.name, column)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd          DateTime  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM  2020-01-08 22:30     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM  2020-01-01 03:30     1      Central
# 2  200110444  04/14/2020 12:00:00 AM  2020-02-13 12:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM  2020-01-01 17:30    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM  2020-01-01 04:15    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex  ... Premis Cd  \
# ...

# %%
df = df.rename(columns={'DateTime': 'Date Occured'})

# %%
df.head()
# Out:
#        DR_NO               Date Rptd      Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM  2020-01-08 22:30     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM  2020-01-01 03:30     1      Central
# 2  200110444  04/14/2020 12:00:00 AM  2020-02-13 12:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM  2020-01-01 17:30    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM  2020-01-01 04:15    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex  ... Premis Cd  \
# ...

# %%
#Checking if there are any duplicate rows
df['DR_NO'].value_counts()
# Out:
# 220200960    1
# 210916583    1
# 211006683    1
# 200508637    1
# 200514782    1
#             ..
# 202013719    1
# 211907592    1
# 202105892    1
# 202107941    1
# 201222877    1
# Name: DR_NO, Length: 820599, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd      Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM  2020-01-08 22:30     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM  2020-01-01 03:30     1      Central
# 2  200110444  04/14/2020 12:00:00 AM  2020-02-13 12:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM  2020-01-01 17:30    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM  2020-01-01 04:15    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
df['Premis Cd'] = df['Premis Cd'].astype(int)
df['Weapon Used Cd'] = df['Weapon Used Cd'].astype(int)
df.drop(['Premis Desc_y'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   Date Occured    820599 non-null  object
#  3   AREA            820599 non-null  int64
#  4   AREA NAME       820599 non-null  object
#  5   Rpt Dist No     820599 non-null  int64
#  6   Crm Cd          820599 non-null  int64
#  7   Crm Cd Desc     820599 non-null  object
#  8   Vict Age        820599 non-null  int64
#  9   Vict Sex        820599 non-null  object
#  10  Vict Descent    820599 non-null  object
#  11  Premis Cd       820599 non-null  int32
#  12  Premis Desc_x   820599 non-null  object
#  13  Weapon Used Cd  820599 non-null  int32
#  14  Weapon Desc     820599 non-null  object
#  15  Status          820599 non-null  object
# ...

# %%
df['Date Occured'] = pd.to_datetime(df['Date Occured'])

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %% [markdown]
# #### 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# **4.1 Visualize overall crime trends from 2020 to the present year**

# %%
import matplotlib.pyplot as plt
import pandas as pd
start_date = "2020-01-01"
end_date = "2023-10-31" 
filtered_data = df[(df["Date Occured"] >= start_date) & (df["Date Occured"] <= end_date)]

crime_trends = filtered_data.groupby(pd.Grouper(key="Date Occured", freq="M")).size()
# print(crime_trends.index)
# print(crime_trends.values)
# print(crime_trends)
# Step 4: Plot the data
plt.figure(figsize=(12, 6))
plt.plot(crime_trends.index, crime_trends.values, marker='o', linestyle='--', color='green')
plt.title("Overall Crime Trends (2020 to Present)")
plt.xlabel("Time")
plt.ylabel("Number of Reported Crimes")
plt.grid(True)
plt.show()

# %% [markdown]
# **4.2 Analyze and visualize seasonal patterns in crime data.**

# %%
import matplotlib.pyplot as plt
import pandas as pd

start_date = "2020-01-01"
end_date = "2023-10-31" 
filtered_data = df[(df["Date Occured"] >= start_date) & (df["Date Occured"] <= end_date)]
crime_trends = filtered_data.groupby(pd.Grouper(key="Date Occured", freq="M")).size()
rolling_avg = crime_trends.rolling(window=12, center=True).mean()  # Use a 12-month rolling window for yearly patterns
plt.figure(figsize=(12, 6))
plt.plot(crime_trends.index, crime_trends.values, label='Monthly Data', color='royalblue', linewidth=1)
plt.plot(rolling_avg.index, rolling_avg.values, label='12-Month Rolling Average', color='orange', linewidth=2)
plt.title("Seasonal Patterns in Crime Data (2020 to Present)", fontsize=16)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Number of Reported Crimes", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Extracting different time components
df['Year'] = df['Date Occured'].dt.year
df['Month'] = df['Date Occured'].dt.month
df['Day'] = df['Date Occured'].dt.day
df['Hour'] = df['Date Occured'].dt.hour

# Analyzing seasonal patterns
# For example, you can analyze the number of crimes per month or per hour using groupby
monthly_crime = df.groupby('Month').size()
hourly_crime = df.groupby('Hour').size()

# Creating visualizations
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
monthly_crime.plot(kind='bar')
plt.title('Number of Crimes per Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')

plt.subplot(1, 2, 2)
hourly_crime.plot(kind='line', marker='o')
plt.title('Number of Crimes per Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Crimes')

plt.tight_layout()
plt.show()

# %% [markdown]
# **4.3 Identify the most common type of crime and its trends over time**

# %%
import matplotlib.pyplot as plt
import pandas as pd
crime_type_counts = df['Crm Cd Desc'].value_counts()
# Identifying the most common crime type
most_common_crime = crime_type_counts.idxmax()
most_common_crime_count = crime_type_counts.max()
print(f"The most common type of crime is '{most_common_crime}' with {most_common_crime_count} reported incidents.")
# Time Series Analysis
# Group data by month and count incidents for the most common crime
df['Month'] = df['Date Occured'].dt.to_period('M')
most_common_crime_data = df[df['Crm Cd Desc'] == most_common_crime].groupby('Month').size()

plt.figure(figsize=(12, 6))
most_common_crime_data.plot(kind='line', color='red')
plt.title(f"Trends in '{most_common_crime}' Over Time")
plt.xlabel("Time (Month)")
plt.ylabel("Number of Reported Incidents")
plt.grid(True)
plt.show()
# Out:
# The most common type of crime is 'VEHICLE - STOLEN' with 87888 reported incidents.

# %%
# Grouping by 'AREA NAME' to analyze the crime rate for each area
crime_rate_by_area = df['AREA NAME'].value_counts()

# Creating a bar plot to compare the crime rates between different areas
plt.figure(figsize=(10, 6))
crime_rate_by_area.plot(kind='bar', color='skyblue')
plt.title('Crime Rate by Area Name')
plt.xlabel('Area Name')
plt.ylabel('Number of Crimes')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **4.4 Investigate if there are any notable differences in crime rates between regions or cities.**

# %%
import matplotlib.pyplot as plt
import pandas as pd
start_date = "2020-01-01"
end_date = "2023-10-31"

if 'Date Occured' in df:
    filtered_data = df[(df['Date Occured'] >= start_date) & (df['Date Occured'] <= end_date)]
    crime_counts_by_region = filtered_data['AREA NAME'].value_counts()
    # Sorting the regions by the number of reported crimes in descending order
    crime_counts_by_region = crime_counts_by_region.sort_values(ascending=False)
    # Create a visually appealing bar plot
    plt.figure(figsize=(12, 6))
    ax = crime_counts_by_region.plot(kind='bar', color='lightgreen', edgecolor='darkgreen')
    ax.set_title("Number of Reported Crimes by Region (2020 to Present)", fontsize=16)
    ax.set_xlabel("Region", fontsize=12)
    ax.set_ylabel("Number of Reported Crimes", fontsize=12)
    ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', linestyle='-', alpha=0.7)
    # Add data labels above each bar
    for bar, count in zip(ax.patches, crime_counts_by_region):
        ax.text(
            bar.get_x() + bar.get_width() / 2, bar.get_height() + 5, count, ha='center',
            fontsize=10, color='black', fontweight='bold'
        )

    # Show the plot
    plt.tight_layout()
    plt.show()
else:
    print("The 'DATE OCC' column is not in the DataFrame. Please check the column name and data.")

# %% [markdown]
# **The code filters and groups crime data by regions, then counts the absolute number of reported crimes in each region. It subsequently creates a bar plot to visually compare the number of reported crimes between different regions, with the regions sorted by the highest crime counts at the top. This analysis provides insight into variations in crime occurrences across different regions or areas in the dataset, without considering population data.**

# %% [markdown]
# **4. 5 Explore correlations between economic factors (if available) and crime rates.**

# %%
df2 = pd.read_csv('EconomicData.csv')

# %%
df2.head()
# Out:
#      Date  Economic metrics
# 0  1/1/20             851.3
# 1  2/1/20             841.0
# 2  3/1/20             831.5
# 3  4/1/20             696.1
# 4  5/1/20             705.6

# %%
df['month'] = df['Date Occured'].dt.month
df['year'] = df['Date Occured'].dt.year

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
df['day'] = 1

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
df['DT'] = pd.to_datetime(df[['year', 'month', 'day']])

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
df.drop(['month','year','day'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
date_counts = df.groupby('DT').size().reset_index(name='counts')

# %%
date_counts
# Out:
#            DT  counts
# 0  2020-01-01   18485
# 1  2020-02-01   17252
# 2  2020-03-01   16161
# 3  2020-04-01   15678
# 4  2020-05-01   17200
# 5  2020-06-01   17028
# 6  2020-07-01   17114
# 7  2020-08-01   16870
# 8  2020-09-01   15631
# 9  2020-10-01   16485
# 10 2020-11-01   15565
# 11 2020-12-01   15940
# 12 2021-01-01   16536
# 13 2021-02-01   15405
# 14 2021-03-01   16315
# 15 2021-04-01   16054
# 16 2021-05-01   16988
# 17 2021-06-01   17146
# 18 2021-07-01   18655
# 19 2021-08-01   18368
# 20 2021-09-01   18351
# 21 2021-10-01   19290
# 22 2021-11-01   18327
# 23 2021-12-01   17918
# 24 2022-01-01   18434
# 25 2022-02-01   17690
# 26 2022-03-01   19682
# 27 2022-04-01   19779
# 28 2022-05-01   20402
# 29 2022-06-01   20189
# 30 2022-07-01   19933
# 31 2022-08-01   20067
# 32 2022-09-01   19264
# 33 2022-10-01   20238
# 34 2022-11-01   18660
# 35 2022-12-01   19889
# 36 2023-01-01   19573
# 37 2023-02-01   18271
# 38 2023-03-01   18977
# 39 2023-04-01   18703
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              45 non-null     object
#  1   Economic metrics  45 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 848.0+ bytes

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.head()
# Out:
#         Date  Economic metrics
# 0 2020-01-01             851.3
# 1 2020-02-01             841.0
# 2 2020-03-01             831.5
# 3 2020-04-01             696.1
# 4 2020-05-01             705.6

# %%
merged_df = pd.merge(date_counts, df2, left_on='DT', right_on='Date')

# %%
#date_counts.info()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              45 non-null     datetime64[ns]
#  1   Economic metrics  45 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 848.0 bytes

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
merged_df
# Out:
#            DT  counts       Date  Economic metrics
# 0  2020-01-01   18485 2020-01-01             851.3
# 1  2020-02-01   17252 2020-02-01             841.0
# 2  2020-03-01   16161 2020-03-01             831.5
# 3  2020-04-01   15678 2020-04-01             696.1
# 4  2020-05-01   17200 2020-05-01             705.6
# 5  2020-06-01   17028 2020-06-01             749.8
# 6  2020-07-01   17114 2020-07-01             761.7
# 7  2020-08-01   16870 2020-08-01             766.9
# 8  2020-09-01   15631 2020-09-01             773.3
# 9  2020-10-01   16485 2020-10-01             795.7
# 10 2020-11-01   15565 2020-11-01             817.9
# 11 2020-12-01   15940 2020-12-01             824.8
# 12 2021-01-01   16536 2021-01-01             799.0
# 13 2021-02-01   15405 2021-02-01             798.3
# 14 2021-03-01   16315 2021-03-01             800.6
# 15 2021-04-01   16054 2021-04-01             797.4
# 16 2021-05-01   16988 2021-05-01             800.5
# ...

# %%
merged_df.drop(['Date'],axis=1,inplace=True)

# %%
merged_df1 = merged_df[['counts','Economic metrics']]
merged_df1['Crime metrics'] = merged_df1['counts']
merged_df1.drop(['counts'],axis=1,inplace=True)

# %%
correlation_matrix = merged_df1.corr()

# Displaying the correlation matrix
print(correlation_matrix)
# Out:
#                   Economic metrics  Crime metrics
# Economic metrics          1.000000       0.586277
# Crime metrics             0.586277       1.000000

# %%
import seaborn as sns
# Creating a heatmap using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
'''The correlation coefficient between 'counts' and 'Economic metrics' is 0.569616, which is between 0 and 1. This positive value indicates a moderate positive linear relationship between the two variables. This suggests that as one variable (e.g., 'Crime metrics') increases, the other variable ('Economic metrics') tends to increase as well, but not perfectly.'''
# Out:
# "The correlation coefficient between 'counts' and 'Economic metrics' is 0.569616, which is between 0 and 1. This positive value indicates a moderate positive linear relationship between the two variables. This suggests that as one variable (e.g., 'Crime metrics') increases, the other variable ('Economic metrics') tends to increase as well, but not perfectly."

# %% [markdown]
# **4.6 Analyze the relationship between the day of the week and the frequency of certain
# types of crimes**

# %%
top_occurrences
# Out:
#                                             Top_Crimes  Occurrences
# 0                                     VEHICLE - STOLEN        87888
# 1                             BATTERY - SIMPLE ASSAULT        65360
# 2                                    THEFT OF IDENTITY        51944
# 3                                BURGLARY FROM VEHICLE        50275
# 4    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        50019
# 5                                             BURGLARY        49955
# 6       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        47235
# 7                   THEFT PLAIN - PETTY ($950 & UNDER)        41704
# 8                    INTIMATE PARTNER - SIMPLE ASSAULT        41355
# 9      THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        31696
# 10   THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        29758
# 11                                             ROBBERY        28142
# 12   THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        26694
# ...

# %%
df['Day_of_Week']=df['DT'].dt.day_name()

# %%
grouped_data = df.groupby(['Day_of_Week', 'Crm Cd Desc']).size().reset_index(name='Frequency')

# Identify the top 10 types of crimes based on frequency
top_10_crimes = grouped_data.groupby('Crm Cd Desc').sum().nlargest(10, 'Frequency').index

# Filter the DataFrame for the top 10 types of crimes
top_10_crimes_df = grouped_data[grouped_data['Crm Cd Desc'].isin(top_10_crimes)]

# Create a bar plot to represent the relationship between the day of the week and the frequency of the top 10 types of crimes
plt.figure(figsize=(12, 6))
for crime in top_10_crimes:
    data = top_10_crimes_df[top_10_crimes_df['Crm Cd Desc'] == crime]
    plt.plot(data['Day_of_Week'], data['Frequency'], marker='o', label=crime)

plt.title('Frequency of Top 10 Crimes by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **The Question 4.7 Investigate any impact of major events or policy changes on crime rates is answerd at the end of this file.**

# %% [markdown]
# **5.1 Advanced Analysis (Optional):**
#
# **Use predictive modeling techniques to predict future crime trends.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming you have a DataFrame 'df' containing the data, and 'DT' is the date column
df['DT'] = pd.to_datetime(df['DT'])

# Grouping by 'DT' and counting the occurrences of crime
crime_occurrences = df['DT'].value_counts().sort_index()

# Plotting the time series data
crime_occurrences.plot(figsize=(12, 6))
plt.title('Crime Occurrences over Time')
plt.xlabel('Date')
plt.ylabel('Number of Occurrences')
plt.show()

# Fitting the ARIMA model
model = ARIMA(crime_occurrences, order=(5, 1, 0))  # Example ARIMA parameters, tune as needed
model_fit = model.fit()

# Forecasting future crime occurrences
future_forecast = model_fit.predict(start=len(crime_occurrences), end=len(crime_occurrences) + 48, typ='levels')  # Forecasting for 48 periods (months)

# Creating future date index till 2025
future_dates = pd.date_range(start=crime_occurrences.index[-1], periods=49, freq='M')

# Creating a DataFrame for future predictions
future_df = pd.DataFrame({'Date': future_dates, 'Forecasted Crime Occurrences': future_forecast})
future_df.set_index('Date', inplace=True)

# Plotting the forecasted data
plt.figure(figsize=(12, 6))
plt.plot(crime_occurrences, label='Observed')
plt.plot(future_df, label='Forecasted', linestyle='dashed')
plt.title('Crime Occurrences Time Series Forecast')
plt.xlabel('Date')
plt.ylabel('Number of Occurrences')
plt.legend()
plt.show()
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Assuming you have a DataFrame 'df' containing the data, and 'DT' is the date column
# df['DT'] = pd.to_datetime(df['DT'])

# Grouping by 'DT' and counting the occurrences of crime
crime_occurrences = df['DT'].value_counts().sort_index()

# Creating a time series for analysis
crime_series = pd.Series(crime_occurrences, index=pd.to_datetime(crime_occurrences.index))

# Fitting the Exponential Smoothing model
model = ExponentialSmoothing(crime_series, seasonal='add', seasonal_periods=12)  # Example parameters, tune as needed
model_fit = model.fit()

# Forecasting future crime occurrences
future_forecast = model_fit.forecast(steps=24)  # Forecasting for 24 periods (months)

# Creating future date index till 2025
future_dates = pd.date_range(start=crime_series.index[-1], periods=25, freq='M')

# Creating a DataFrame for future predictions
future_df = pd.DataFrame({'Date': future_dates[1:], 'Forecasted Crime Occurrences': future_forecast})
future_df.set_index('Date', inplace=True)

# Plotting the forecasted data
plt.figure(figsize=(12, 6))
plt.plot(crime_series, label='Observed')
plt.plot(future_df, label='Forecasted', linestyle='dashed')
plt.title('Crime Occurrences Time Series Forecast using Exponential Smoothing')
plt.xlabel('Date')
plt.ylabel('Number of Occurrences')
plt.legend()
plt.show()
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\acer\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# **4.7 Investigate any impact of major events or policy changes on crime rates.**

# %%
df3 = pd.read_csv('Events_Excel_Revised.csv')

# %%
df3
# Out:
#         Date                                      Event
# 0    1/26/20                              Grammy Awards
# 1     2/2/20                             Super Bowl LIV
# 2     2/9/20                             Academy Awards
# 3     3/8/20                       Los Angeles Marathon
# 4    2/28/21                        Golden Globe Awards
# 5    4/25/21                             Academy Awards
# 6    2/13/22                             Super Bowl LVI
# 7    3/27/22                             Academy Awards
# 8     4/3/22                              Grammy Awards
# 9     2/5/23                              Grammy Awards
# 10   3/12/23                             Academy Awards
# 11   4/10/20   Coachella Valley Music and Arts Festival
# 12   4/24/20          Stagecoach Country Music Festival
# 13   6/11/20                  Los Angeles Film Festival
# 14    8/9/21   Coachella Valley Music and Arts Festival
# 15   8/23/21          Stagecoach Country Music Festival
# ...

# %%
df3['Date'] = pd.to_datetime(df3['Date'], format='%m/%d/%y').dt.strftime('%Y-%m-%d')

# %%
df3[' Event']
# Out:
# 0                                 Grammy Awards
# 1                                Super Bowl LIV
# 2                                Academy Awards
# 3                          Los Angeles Marathon
# 4                           Golden Globe Awards
# 5                                Academy Awards
# 6                                Super Bowl LVI
# 7                                Academy Awards
# 8                                 Grammy Awards
# 9                                 Grammy Awards
# 10                               Academy Awards
# 11     Coachella Valley Music and Arts Festival
# 12            Stagecoach Country Music Festival
# 13                    Los Angeles Film Festival
# 14     Coachella Valley Music and Arts Festival
# 15            Stagecoach Country Music Festival
# 16                    Los Angeles Film Festival
# 17     Coachella Valley Music and Arts Festival
# 18            Stagecoach Country Music Festival
# 19                    Los Angeles Film Festival
# ...

# %%
df.head()
# Out:
#        DR_NO               Date Rptd        Date Occured  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM 2020-01-08 22:30:00     3    Southwest
# 1  190101086  01/02/2020 12:00:00 AM 2020-01-01 03:30:00     1      Central
# 2  200110444  04/14/2020 12:00:00 AM 2020-02-13 12:00:00     1      Central
# 3  191501505  01/01/2020 12:00:00 AM 2020-01-01 17:30:00    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM 2020-01-01 04:15:00    19      Mission
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          377     624                           BATTERY - SIMPLE ASSAULT
# 1          163     624                           BATTERY - SIMPLE ASSAULT
# 2          155     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         1543     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         1998     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %%
df.info()
df['Date Occured'] = pd.to_datetime(df['Date Occured'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820599 entries, 0 to 820598
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   Date Occured    820599 non-null  datetime64[ns]
#  3   AREA            820599 non-null  int64
#  4   AREA NAME       820599 non-null  object
#  5   Rpt Dist No     820599 non-null  int64
#  6   Crm Cd          820599 non-null  int64
#  7   Crm Cd Desc     820599 non-null  object
#  8   Vict Age        820599 non-null  int64
#  9   Vict Sex        820599 non-null  object
#  10  Vict Descent    820599 non-null  object
#  11  Premis Cd       820599 non-null  int32
#  12  Premis Desc_x   820599 non-null  object
#  13  Weapon Used Cd  820599 non-null  int32
#  14  Weapon Desc     820599 non-null  object
#  15  Status          820599 non-null  object
# ...

# %%
df['Date_'] = df['Date Occured'].dt.date

# %%
# Grouping by 'DT' and counting the occurrences of crime
crime_occurrences = df['Date_'].value_counts().sort_index()

# Creating a DataFrame for the occurrences of crime in a day
occurrences_df = pd.DataFrame({'Date': crime_occurrences.index, 'Occurrences': crime_occurrences.values})

# Displaying the DataFrame
print(occurrences_df)
# Out:
#             Date  Occurrences
# 0     2020-01-01         1107
# 1     2020-01-02          527
# 2     2020-01-03          595
# 3     2020-01-04          540
# 4     2020-01-05          505
# 5     2020-01-06          593
# 6     2020-01-07          538
# 7     2020-01-08          537
# 8     2020-01-09          575
# 9     2020-01-10          625
# 10    2020-01-11          547
# 11    2020-01-12          518
# 12    2020-01-13          559
# 13    2020-01-14          552
# 14    2020-01-15          619
# 15    2020-01-16          591
# 16    2020-01-17          639
# 17    2020-01-18          565
# 18    2020-01-19          575
# 19    2020-01-20          589
# 20    2020-01-21          593
# 21    2020-01-22          567
# 22    2020-01-23          588
# 23    2020-01-24          619
# 24    2020-01-25          595
# 25    2020-01-26          598
# 26    2020-01-27          590
# 27    2020-01-28          604
# 28    2020-01-29          589
# 29    2020-01-30          588
# ...

# %%
occurrences_df
# Out:
#             Date  Occurrences
# 0     2020-01-01         1107
# 1     2020-01-02          527
# 2     2020-01-03          595
# 3     2020-01-04          540
# 4     2020-01-05          505
# 5     2020-01-06          593
# 6     2020-01-07          538
# 7     2020-01-08          537
# 8     2020-01-09          575
# 9     2020-01-10          625
# 10    2020-01-11          547
# 11    2020-01-12          518
# 12    2020-01-13          559
# 13    2020-01-14          552
# 14    2020-01-15          619
# 15    2020-01-16          591
# 16    2020-01-17          639
# 17    2020-01-18          565
# 18    2020-01-19          575
# 19    2020-01-20          589
# 20    2020-01-21          593
# 21    2020-01-22          567
# 22    2020-01-23          588
# 23    2020-01-24          619
# 24    2020-01-25          595
# 25    2020-01-26          598
# 26    2020-01-27          590
# 27    2020-01-28          604
# 28    2020-01-29          589
# 29    2020-01-30          588
# ...

# %%
# Converting 'Date' columns to datetime format
df3['Date'] = pd.to_datetime(df3['Date'])
occurrences_df['Date'] = pd.to_datetime(occurrences_df['Date'])



# Displaying the merged DataFrame
merged_df = pd.merge(df3, occurrences_df,on='Date')

# %%
merged_df
# Out:
#          Date                                      Event  Occurrences
# 0  2020-01-26                              Grammy Awards          598
# 1  2020-02-02                             Super Bowl LIV          668
# 2  2020-02-09                             Academy Awards          520
# 3  2020-03-08                       Los Angeles Marathon          544
# 4  2021-02-28                        Golden Globe Awards          539
# 5  2021-04-25                             Academy Awards          542
# 6  2022-02-13                             Super Bowl LVI          704
# 7  2022-03-27                             Academy Awards          553
# 8  2022-04-03                              Grammy Awards          825
# 9  2023-02-05                              Grammy Awards          663
# 10 2023-03-12                             Academy Awards          571
# 11 2020-04-10   Coachella Valley Music and Arts Festival          545
# ...

# %%
# Creating a histogram
plt.figure(figsize=(10, 6))
plt.bar(merged_df[' Event'], merged_df['Occurrences'], color='skyblue')
plt.title('Occurrences of Events')
plt.xlabel('Event')
plt.ylabel('Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
